# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("500_Person_Gender_Height_Weight_Index.csv")
df = df.drop('Index', axis=1)
df.head()
# Out:
#    Gender  Height  Weight
# 0    Male     174      96
# 1    Male     189      87
# 2  Female     185     110
# 3  Female     195     104
# 4    Male     149      61

# %%
df.plot (kind = 'scatter',x = 'Height', y = 'Weight', title = "W")
# Out:
# <AxesSubplot:title={'center':'W'}, xlabel='Height', ylabel='Weight'>

# %%
x1 = np.array(df['Height']).reshape(-1,1)
X
# Out:
# array([[174],
#        [189],
#        [185],
#        [195],
#        [149],
#        [189],
#        [147],
#        [154],
#        [174],
#        [169],
#        [195],
#        [159],
#        [192],
#        [155],
#        [191],
#        [153],
#        [157],
#        [140],
#        [144],
#        [172],
#        [157],
#        [153],
#        [169],
#        [185],
#        [172],
#        [151],
#        [190],
#        [187],
#        [163],
#        [179],
#        [153],
#        [178],
#        [195],
#        [160],
#        [157],
#        [189],
#        [197],
#        [144],
#        [171],
#        [185],
#        [175],
#        [149],
#        [157],
#        [161],
#        [182],
#        [185],
#        [188],
#        [181],
#        [161],
#        [140],
#        [168],
#        [176],
#        [163],
#        [172],
#        [196],
#        [187],
#        [172],
#        [178],
#        [164],
#        [143],
#        [191],
#        [141],
# ...

# %%
Y = np.array(df['Weight']).reshape(-1,1)
Y
# Out:
# array([[ 96],
#        [ 87],
#        [110],
#        [104],
#        [ 61],
#        [104],
#        [ 92],
#        [111],
#        [ 90],
#        [103],
#        [ 81],
#        [ 80],
#        [101],
#        [ 51],
#        [ 79],
#        [107],
#        [110],
#        [129],
#        [145],
#        [139],
#        [110],
#        [149],
#        [ 97],
#        [139],
#        [ 67],
#        [ 64],
#        [ 95],
#        [ 62],
#        [159],
#        [152],
#        [121],
#        [ 52],
#        [ 65],
#        [131],
#        [153],
#        [132],
#        [114],
#        [ 80],
#        [152],
#        [ 81],
#        [120],
#        [108],
#        [ 56],
#        [118],
#        [126],
#        [ 76],
#        [122],
#        [111],
#        [ 72],
#        [152],
#        [135],
#        [ 54],
#        [110],
#        [105],
#        [116],
#        [ 89],
#        [ 92],
#        [127],
#        [ 70],
#        [ 88],
#        [ 54],
#        [143],
# ...

# %%
regression = LinearRegression()
regression.fit(x1,Y)
# Out:
# LinearRegression()

# %%
w = regression.coef_

# %%
b = regression.intercept_

# %%
x2 = np.linspace(55,80,100).reshape(-1,1)

# %%
yhat = regression.predict(x)

# %%
df.plot (kind = 'scatter', x = 'Height', y = 'Weight',title = "W")
plt.plot(x2,yhat,color = 'red',linewidth = 3)
